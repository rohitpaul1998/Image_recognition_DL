# %%
# getting an image using web get

# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# --2024-04-08 11:58:45--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 65.8.178.91, 65.8.178.27, 65.8.178.73, ...
# Connecting to tractive.com (tractive.com)|65.8.178.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg’
#
# puppy-care-guide-fo 100%[===================>] 110.91K  --.-KB/s    in 0.05s
#
# 2024-04-08 11:58:45 (2.33 MB/s) - ‘puppy-care-guide-for-new-parents.jpg’ saved [113570/113570]

# %% [markdown]
# **Libraries that can be used for image processing:**
#
# 1. matplotlib.image
#
# 2. Pillow
#
# 3. OpenCV (cv2)

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('/content/Puppy1.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1330, 1920, 3)

# %%
print(img)
# Out:
# [[[225 228 233]
#   [225 228 233]
#   [225 228 233]
#   ...
#   [160 159 155]
#   [159 158 154]
#   [159 158 154]]
#
#  [[225 228 233]
#   [225 228 233]
#   [225 228 233]
#   ...
#   [159 158 154]
#   [159 158 154]
#   [159 158 154]]
#
#  [[225 228 233]
#   [225 228 233]
#   [225 228 233]
#   ...
#   [158 157 153]
#   [158 157 153]
#   [158 157 153]]
#
#  ...
#
#  [[123 114  57]
#   [124 115  58]
#   [125 116  57]
#   ...
#   [ 97  91  39]
#   [ 98  92  40]
#   [ 98  92  40]]
#
#  [[125 119  61]
#   [125 119  61]
#   [125 119  61]
#   ...
#   [ 97  91  41]
#   [ 97  91  41]
#   [ 98  92  42]]
#
#  [[125 119  61]
#   [125 119  61]
#   [125 119  61]
#   ...
#   [ 97  91  41]
#   [ 97  91  41]
#   [ 98  92  42]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/Puppy1.jpeg')
img_resized = img.resize((200, 200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/Puppy1.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1330, 1920, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1330, 1920)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1920x1330>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
